# %% [markdown]
# # Highlight Custom Data Points with Colors and Text

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('../Data/gapminder-FiveYearData.csv')
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
data.shape
# Out:
# (1704, 6)

# %% [markdown]
# ### - How to highlight select data points in a scatter plot with different color?

# %%
plt.scatter(data['lifeExp'], data['gdpPercap'])
plt.xlabel("Life Expetancy")
plt.ylabel("GDP per Capita")
plt.title("Life Exp Vs GDP per Capita")
plt.show()

# %%
plt.boxplot(x = data['gdpPercap'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f2e687f08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21f2e668148>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21f2e6870c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f2e68fe88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f2e68ff08>],
#  'means': []}

# %%
#Subsetting our data to contain only outliers
df = data[(data['lifeExp'] > 50) & (data['gdpPercap']  > 50000)]
df
# Out:
#     country  year        pop continent  lifeExp     gdpPercap
# 852  Kuwait  1952   160000.0      Asia   55.565  108382.35290
# 853  Kuwait  1957   212846.0      Asia   58.033  113523.13290
# 854  Kuwait  1962   358266.0      Asia   60.470   95458.11176
# 855  Kuwait  1967   575003.0      Asia   64.624   80894.88326
# 856  Kuwait  1972   841934.0      Asia   67.712  109347.86700
# 857  Kuwait  1977  1140357.0      Asia   69.343   59265.47714

# %%
df = data.query('lifeExp > 50 & gdpPercap > 50000')
df.shape
# Out:
# (6, 6)

# %% [markdown]
# #### To start with we will first make scatter plot exactly as before between the two variables. Here we have just changed the title of the plot.

# %%
plt.scatter(data['lifeExp'], data['gdpPercap'], alpha = 0.5)
plt.xlabel("Life Expetancy")
plt.ylabel("GDP per Capita")
plt.title("Life Exp Vs GDP per Capita Highlited Outliers")
plt.scatter(df.lifeExp, df.gdpPercap, c = 'r')
plt.show()

# %% [markdown]
# ### - How to highlight select data points with different color and annotate with text?

# %% [markdown]
# `Matplotlib has a function named annotate() to add text in a specific location in a plot. We need to specify annotate() function the text we want to annotate the plot with and the x and y co-ordinates for the location of the text.`

# %%
plt.scatter(data['lifeExp'], data['gdpPercap'], alpha = 0.5)
plt.xlabel("Life Expetancy")
plt.ylabel("GDP per Capita")
plt.title("Life Exp Vs GDP per Capita Highlited Outliers")
plt.scatter(df.lifeExp, df.gdpPercap, c = 'r')

# loop through to annotate multiple datapoints
for i in range(df.shape[0]):
    plt.annotate(df.country.tolist()[i], (df.lifeExp.tolist()[i], df.gdpPercap.tolist()[i]))
print(df.shape[0])
plt.tight_layout()
plt.show()
# Out:
# 6
